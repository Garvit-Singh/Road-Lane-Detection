# %% [markdown]
# # Libraries

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import torchvision.transforms as transforms
import torchvision.transforms.functional as TF

# colab libraries
from google.colab import drive
from google.colab.patches import cv2_imshow

import os
import cv2
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from tqdm import tqdm

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Seeding

# %%
torch.manual_seed(784)

# %%
np.random.seed(54)

# %% [markdown]
# # Data Processing

# %% [markdown]
# ## Mount Drive

# %%
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
BASE_PATH = '/content/drive/MyDrive/DL Project/Project Dataset'
TRAIN_PATH = BASE_PATH + '/train_unzipped'
TRAIN_LABEL_PATH = BASE_PATH + '/train_label_unzipped'
VAL_PATH = BASE_PATH + '/val_unzipped'
VAL_LABEL_PATH = BASE_PATH + '/val_label_unzipped'

# %% [markdown]
# ## Load Data

# %%
def import_data(INPUT_PATH: str, LABEL_PATH: str, final_dimension: tuple, input_id_index : tuple, label_id_index : tuple, is_val: bool = False):

    inputs = []
    labels = []

    files = os.listdir(INPUT_PATH)
    label_files = os.listdir(LABEL_PATH)

    for index, file in enumerate(files):
        
        if (not is_val) and index % 3 > 0:
            continue

        try:
            idx = (int) (file[ input_id_index[0] : input_id_index[1] ])
        except:
            continue

        image = cv2.imread(INPUT_PATH+"/"+file)
        image = cv2.resize(image, final_dimension)
        inputs.append(image)

        for label_file in label_files:
        
            label_idx = (int)(label_file[ label_id_index[0] : label_id_index[1] ])

            if(idx == label_idx):
                label_image = cv2.imread(LABEL_PATH+"/"+label_file)
                label_image = cv2.resize(label_image, final_dimension)
                labels.append(label_image)
                break

    inputs = np.array(inputs)
    inputs = inputs/255
    labels = np.array(labels)
    labels = labels/255

    return (inputs, labels)

# %%
reduced_dims = (192, 96)

# %%
# the below 4 variables denotes the idx indices for the file names

train_input_id_index = (44, -4)   # Example: Town04_Clear_Noon_09_09_2020_14_57_22_frame_0.png
train_label_id_index = (44, -10)  # Example: Town04_Clear_Noon_09_09_2020_14_57_22_frame_0_label.png

val_input_id_index = (44, -19)    # Example: Town04_Clear_Noon_09_09_2020_14_57_22_frame_100_validation_set.png
val_label_id_index = (44, -25)    # Example: Town04_Clear_Noon_09_09_2020_14_57_22_frame_100_validation_set_label.png

# %%
train_x, train_y = import_data(TRAIN_PATH, TRAIN_LABEL_PATH, reduced_dims, train_input_id_index, train_label_id_index)
val_x, val_y = import_data(VAL_PATH, VAL_LABEL_PATH, reduced_dims, val_input_id_index, val_label_id_index, True)

# %%
print(train_x.shape, train_y.shape)
print(val_x.shape, val_y.shape)
# Out:
# (1026, 96, 192, 3) (1026, 96, 192, 3)
# (129, 96, 192, 3) (129, 96, 192, 3)

# %% [markdown]
# ## Data Visualising

# %%
i = np.random.randint(0, len(train_x))
plt.imshow(train_x[i])
plt.title(f"Training example #{i}")
plt.show()
plt.imshow(train_y[i]*100)
plt.show()

# %% [markdown]
# # Model Architecture

# %%
class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(DoubleConv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, 1, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, 3, 1, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):
        return self.conv(x)

class UNET(nn.Module):
    def __init__(
            self, in_channels=3, out_channels=1, features=[32, 64, 128, 256],
    ):
        super(UNET, self).__init__()
        self.ups = nn.ModuleList()
        self.downs = nn.ModuleList()
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.sigmoid = nn.Sigmoid()

        # Down part of UNET
        for feature in features:
            self.downs.append(DoubleConv(in_channels, feature))
            in_channels = feature

        # Up part of UNET
        for feature in reversed(features):
            self.ups.append(
                nn.ConvTranspose2d(
                    feature*2, feature, kernel_size=2, stride=2,
                )
            )
            self.ups.append(DoubleConv(feature*2, feature))

        self.bottleneck = DoubleConv(features[-1], features[-1]*2)
        self.final_conv = nn.Conv2d(features[0], out_channels, kernel_size=1)

    def forward(self, x):
        skip_connections = []

        for down in self.downs:
            x = down(x)
            skip_connections.append(x)
            x = self.pool(x)

        x = self.bottleneck(x)
        skip_connections = skip_connections[::-1]

        for idx in range(0, len(self.ups), 2):
            x = self.ups[idx](x)
            skip_connection = skip_connections[idx//2]

            if x.shape != skip_connection.shape:
                x = TF.resize(x, size=skip_connection.shape[2:])

            concat_skip = torch.cat((skip_connection, x), dim=1)
            x = self.ups[idx+1](concat_skip)
        x = self.final_conv(x)
        return self.sigmoid(x)

# %% [markdown]
# #### Model Summary

# %%
input_dim = (3, 96, 192)

# %%
from torchsummary import summary
testing_model = UNET()

# while working on GPU
summary(testing_model.cuda(), input_dim)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 32, 96, 192]             864
#        BatchNorm2d-2          [-1, 32, 96, 192]              64
#               ReLU-3          [-1, 32, 96, 192]               0
#             Conv2d-4          [-1, 32, 96, 192]           9,216
#        BatchNorm2d-5          [-1, 32, 96, 192]              64
#               ReLU-6          [-1, 32, 96, 192]               0
#         DoubleConv-7          [-1, 32, 96, 192]               0
#          MaxPool2d-8           [-1, 32, 48, 96]               0
#             Conv2d-9           [-1, 64, 48, 96]          18,432
#       BatchNorm2d-10           [-1, 64, 48, 96]             128
#              ReLU-11           [-1, 64, 48, 96]               0
#            Conv2d-12           [-1, 64, 48, 96]          36,864
#       BatchNorm2d-13           [-1, 64, 48, 96]             128
#              ReLU-14           [-1, 64, 48, 96]               0
#        DoubleConv-15           [-1, 64, 48, 96]               0
#         MaxPool2d-16           [-1, 64, 24, 48]               0
#            Conv2d-17          [-1, 128, 24, 48]          73,728
#       BatchNorm2d-18          [-1, 128, 24, 48]             256
#              ReLU-19          [-1, 128, 24, 48]               0
#            Conv2d-20          [-1, 128, 24, 48]         147,456
#       BatchNorm2d-21          [-1, 128, 24, 48]             256
#              ReLU-22          [-1, 128, 24, 48]               0
#        DoubleConv-23          [-1, 128, 24, 48]               0
#         MaxPool2d-24          [-1, 128, 12, 24]               0
#            Conv2d-25          [-1, 256, 12, 24]         294,912
#       BatchNorm2d-26          [-1, 256, 12, 24]             512
#              ReLU-27          [-1, 256, 12, 24]               0
#            Conv2d-28          [-1, 256, 12, 24]         589,824
#       BatchNorm2d-29          [-1, 256, 12, 24]             512
#              ReLU-30          [-1, 256, 12, 24]               0
#        DoubleConv-31          [-1, 256, 12, 24]               0
#         MaxPool2d-32           [-1, 256, 6, 12]               0
#            Conv2d-33           [-1, 512, 6, 12]       1,179,648
#       BatchNorm2d-34           [-1, 512, 6, 12]           1,024
#              ReLU-35           [-1, 512, 6, 12]               0
#            Conv2d-36           [-1, 512, 6, 12]       2,359,296
#       BatchNorm2d-37           [-1, 512, 6, 12]           1,024
#              ReLU-38           [-1, 512, 6, 12]               0
#        DoubleConv-39           [-1, 512, 6, 12]               0
#   ConvTranspose2d-40          [-1, 256, 12, 24]         524,544
#            Conv2d-41          [-1, 256, 12, 24]       1,179,648
#       BatchNorm2d-42          [-1, 256, 12, 24]             512
#              ReLU-43          [-1, 256, 12, 24]               0
#            Conv2d-44          [-1, 256, 12, 24]         589,824
#       BatchNorm2d-45          [-1, 256, 12, 24]             512
#              ReLU-46          [-1, 256, 12, 24]               0
#        DoubleConv-47          [-1, 256, 12, 24]               0
#   ConvTranspose2d-48          [-1, 128, 24, 48]         131,200
#            Conv2d-49          [-1, 128, 24, 48]         294,912
#       BatchNorm2d-50          [-1, 128, 24, 48]             256
#              ReLU-51          [-1, 128, 24, 48]               0
#            Conv2d-52          [-1, 128, 24, 48]         147,456
#       BatchNorm2d-53          [-1, 128, 24, 48]             256
#              ReLU-54          [-1, 128, 24, 48]               0
#        DoubleConv-55          [-1, 128, 24, 48]               0
#   ConvTranspose2d-56           [-1, 64, 48, 96]          32,832
#            Conv2d-57           [-1, 64, 48, 96]          73,728
#       BatchNorm2d-58           [-1, 64, 48, 96]             128
#              ReLU-59           [-1, 64, 48, 96]               0
#            Conv2d-60           [-1, 64, 48, 96]          36,864
#       BatchNorm2d-61           [-1, 64, 48, 96]             128
#              ReLU-62           [-1, 64, 48, 96]               0
#        DoubleConv-63           [-1, 64, 48, 96]               0
#   ConvTranspose2d-64          [-1, 32, 96, 192]           8,224
#            Conv2d-65          [-1, 32, 96, 192]          18,432
#       BatchNorm2d-66          [-1, 32, 96, 192]              64
#              ReLU-67          [-1, 32, 96, 192]               0
#            Conv2d-68          [-1, 32, 96, 192]           9,216
#       BatchNorm2d-69          [-1, 32, 96, 192]              64
#              ReLU-70          [-1, 32, 96, 192]               0
#        DoubleConv-71          [-1, 32, 96, 192]               0
#            Conv2d-72           [-1, 1, 96, 192]              33
#           Sigmoid-73           [-1, 1, 96, 192]               0
# ================================================================
# Total params: 7,763,041
# Trainable params: 7,763,041
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.21
# Forward/backward pass size (MB): 130.92
# Params size (MB): 29.61
# Estimated Total Size (MB): 160.75
# ----------------------------------------------------------------

# %% [markdown]
# # Ground

# %% [markdown]
# ## Train Preprocessing

# %%
n, h, w, c = train_y.shape          # 1026 x 96 x 192 x 3
shape_ground = (n, h, w, 1)

# %%
ground = np.zeros(shape=shape_ground)   # 1026 x 96 x 192 x 1
back_ground_limit = 0.0

# %%
def get_ground_for_each_train(y_train):
    n, h, w, c = y_train.shape          # 1026 x 96 x 192 x 3
    for i in range(n):
        ground[i] = np.where(np.mean(y_train[i], axis=2, keepdims=True) <= back_ground_limit, 0, 1)
    return

# %%
get_ground_for_each_train(train_y)

# %%
ground.shape
# Out:
# (1026, 96, 192, 1)

# %% [markdown]
# ##### Train Ground Visual

# %%
broad_caster = broad_caster = np.ones(shape=(96, 192, 3))

# %%
i = np.random.randint(0, len(train_y))
plt.imshow(train_y[i]*100)
plt.title(f"Training example #{i}")
plt.show()
plt.imshow(ground[i]*broad_caster*100)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Validation Preprocessing

# %%
n, h, w, c = val_y.shape          # 1026 x 96 x 192 x 3
shape_val = (n, h, w, 1)

# %%
val_ground = np.zeros(shape=shape_val)

# %%
def get_ground_for_each_val(y_test):
    n, h, w, c = y_test.shape          # 1026 x 96 x 192 x 3
    for i in range(n):
        val_ground[i] = np.where(np.mean(y_test[i], axis=2, keepdims=True) <= back_ground_limit, 0, 1)
    return

# %%
get_ground_for_each_val(val_y)

# %%
val_ground.shape
# Out:
# (129, 96, 192, 1)

# %% [markdown]
# # Loss Function

# %% [markdown]
# #### BCEDice Loss

# %%
class DiceLoss(nn.Module):
    def __init__(self, weight=None, size_average=True, smooth=1e-6):
        super(DiceLoss, self).__init__()
        self.smooth = smooth
        
    def forward(self, inputs, targets):
        #flatten label and prediction tensors
        inputs = torch.flatten(inputs)
        targets = torch.flatten(targets)
        
        BCE =  nn.BCEWithLogitsLoss()
        BCE = BCE(inputs, targets)
        intersection = torch.sum(torch.dot(targets, inputs))    
        dice_loss = 1 - (2*intersection + self.smooth) / (torch.sum(targets) + torch.sum(inputs) + self.smooth)
        Dice_BCE = BCE + dice_loss
        
        return Dice_BCE

# %% [markdown]
# # Learning

# %% [markdown]
# #### Hyperparameters

# %%
lr = 0.01
batch_size = 8
momentum = 0.2
epochs = 100
epsilon = 1e-6

# %% [markdown]
# #### Shapes

# %%
print(train_x.shape , train_y.shape)
# Out:
# (1026, 96, 192, 3) (1026, 96, 192, 3)

# %%
print(val_x.shape, val_y.shape)
# Out:
# (129, 96, 192, 3) (129, 96, 192, 3)

# %%
print(ground.shape)
# Out:
# (1026, 96, 192, 1)

# %%
print(val_ground.shape)
# Out:
# (129, 96, 192, 1)

# %% [markdown]
# #### Model Initialisation

# %%
model = UNET().to(device)

# %% [markdown]
# #### Optimizer

# %%
optimizer = optim.SGD(model.parameters(), lr, momentum)

# %% [markdown]
# #### Loss Class

# %%
dice_loss = DiceLoss(smooth = epsilon)

# %% [markdown]
# #### Weight Initializer

# %%
def initialize_weights(m):
    if isinstance(m, nn.Conv2d):
        nn.init.normal_(m.weight.data, 0, 1)
        if m.bias is not None:
            nn.init.constant_(m.bias.data, 0)
    elif isinstance(m, nn.BatchNorm2d):
        nn.init.normal_(m.weight.data, 0, 1)
        nn.init.constant_(m.bias.data, 0)
    elif isinstance(m, nn.Linear):
        nn.init.normal_(m.weight.data, 0, 1)
        nn.init.constant_(m.bias.data, 0)

# %% [markdown]
# #### Training and Validation

# %%
train_losses = []
validation_losses = []

# %%
model.train()
model.apply(initialize_weights)

n = len(train_x)

for epoch in range(epochs):

    train_loss = 0.0

    for i in range( n//batch_size ):

        optimizer.zero_grad()

        input = torch.from_numpy(train_x[i*batch_size: i*batch_size+batch_size]).float()
        input = input.to(device)

        # changing from batch_size x 96 x 192 x 3 to batch_size x 3 x 96 x 192
        input = input.transpose(1, 3)
        input = input.transpose(2, 3)

        # batch_size x 96 x 192 x 7
        output = torch.from_numpy(ground[i*batch_size: i*batch_size+batch_size]).float()
        output = output.to(device)

        # changing from batch_size x 96 x 192 x 1 to batch_size x 1 x 96 x 192
        output = output.transpose(1, 3)
        output = output.transpose(2, 3)

        # forward
        predictions = model(input)                  # batch_size x 1 x 96 x 192
        loss = dice_loss(predictions, output)

        # backward
        loss.backward()
        optimizer.step()

        # update losses
        train_loss += loss.item()

    print("Loss after epoch " + str(epoch) + " is : " + str(loss.item()))
    train_losses.append(train_loss)
# Out:
# Loss after epoch 0 is : 1.8486518859863281
# Loss after epoch 1 is : 1.7738150358200073
# Loss after epoch 2 is : 1.687804937362671
# Loss after epoch 3 is : 1.5765573978424072
# Loss after epoch 4 is : 1.445812463760376
# Loss after epoch 5 is : 1.3566173315048218
# Loss after epoch 6 is : 1.302095651626587
# Loss after epoch 7 is : 1.2619528770446777
# Loss after epoch 8 is : 1.2298489809036255
# Loss after epoch 9 is : 1.2056236267089844
# Loss after epoch 10 is : 1.1887006759643555
# Loss after epoch 11 is : 1.1751861572265625
# Loss after epoch 12 is : 1.1627814769744873
# Loss after epoch 13 is : 1.1515631675720215
# Loss after epoch 14 is : 1.1411173343658447
# Loss after epoch 15 is : 1.131318211555481
# Loss after epoch 16 is : 1.1219943761825562
# Loss after epoch 17 is : 1.1141328811645508
# Loss after epoch 18 is : 1.1069145202636719
# Loss after epoch 19 is : 1.100366473197937
# Loss after epoch 20 is : 1.0945088863372803
# Loss after epoch 21 is : 1.0890836715698242
# Loss after epoch 22 is : 1.0840039253234863
# Loss after epoch 23 is : 1.0792548656463623
# Loss after epoch 24 is : 1.0746116638183594
# Loss after epoch 25 is : 1.0701115131378174
# Loss after epoch 26 is : 1.0656015872955322
# Loss after epoch 27 is : 1.0611422061920166
# Loss after epoch 28 is : 1.0567283630371094
# Loss after epoch 29 is : 1.0523947477340698
# Loss after epoch 30 is : 1.0481210947036743
# Loss after epoch 31 is : 1.0439443588256836
# Loss after epoch 32 is : 1.0398513078689575
# Loss after epoch 33 is : 1.035897970199585
# Loss after epoch 34 is : 1.0322434902191162
# Loss after epoch 35 is : 1.0289151668548584
# Loss after epoch 36 is : 1.0258510112762451
# Loss after epoch 37 is : 1.0228350162506104
# Loss after epoch 38 is : 1.0199120044708252
# Loss after epoch 39 is : 1.0170693397521973
# Loss after epoch 40 is : 1.014340877532959
# Loss after epoch 41 is : 1.0117391347885132
# Loss after epoch 42 is : 1.009201169013977
# Loss after epoch 43 is : 1.0067332983016968
# Loss after epoch 44 is : 1.0042580366134644
# Loss after epoch 45 is : 1.0017645359039307
# Loss after epoch 46 is : 0.9991610646247864
# Loss after epoch 47 is : 0.9965656399726868
# Loss after epoch 48 is : 0.9939815998077393
# Loss after epoch 49 is : 0.9914417266845703
# Loss after epoch 50 is : 0.9889614582061768
# Loss after epoch 51 is : 0.9866403937339783
# Loss after epoch 52 is : 0.9844985604286194
# Loss after epoch 53 is : 0.9824064373970032
# Loss after epoch 54 is : 0.9803783893585205
# Loss after epoch 55 is : 0.9784286618232727
# Loss after epoch 56 is : 0.9765897989273071
# Loss after epoch 57 is : 0.9748351573944092
# Loss after epoch 58 is : 0.9731800556182861
# Loss after epoch 59 is : 0.9716027975082397
# Loss after epoch 60 is : 0.97007817029953
# Loss after epoch 61 is : 0.9686698317527771
# Loss after epoch 62 is : 0.9672800898551941
# Loss after epoch 63 is : 0.9659558534622192
# Loss after epoch 64 is : 0.9646324515342712
# Loss after epoch 65 is : 0.9633628726005554
# Loss after epoch 66 is : 0.9621001482009888
# Loss after epoch 67 is : 0.9608449935913086
# Loss after epoch 68 is : 0.95958012342453
# Loss after epoch 69 is : 0.9582908749580383
# Loss after epoch 70 is : 0.9570661187171936
# Loss after epoch 71 is : 0.9558552503585815
# Loss after epoch 72 is : 0.9546835422515869
# Loss after epoch 73 is : 0.9535506367683411
# Loss after epoch 74 is : 0.9524142146110535
# Loss after epoch 75 is : 0.9512605667114258
# Loss after epoch 76 is : 0.9501470327377319
# Loss after epoch 77 is : 0.9490774273872375
# Loss after epoch 78 is : 0.9480376839637756
# Loss after epoch 79 is : 0.946995198726654
# Loss after epoch 80 is : 0.9459744095802307
# Loss after epoch 81 is : 0.9449673891067505
# Loss after epoch 82 is : 0.9439771771430969
# Loss after epoch 83 is : 0.943011999130249
# Loss after epoch 84 is : 0.9420604705810547
# Loss after epoch 85 is : 0.9411192536354065
# Loss after epoch 86 is : 0.94017493724823
# Loss after epoch 87 is : 0.9392867684364319
# Loss after epoch 88 is : 0.9384227395057678
# Loss after epoch 89 is : 0.9375506043434143
# Loss after epoch 90 is : 0.9366620779037476
# Loss after epoch 91 is : 0.9358036518096924
# Loss after epoch 92 is : 0.9349513649940491
# Loss after epoch 93 is : 0.9341040253639221
# Loss after epoch 94 is : 0.9332799315452576
# Loss after epoch 95 is : 0.9324541091918945
# Loss after epoch 96 is : 0.9316613674163818
# Loss after epoch 97 is : 0.9308993816375732
# Loss after epoch 98 is : 0.9301376938819885
# Loss after epoch 99 is : 0.9294309616088867

# %%
validation_accuracy = []

# %%
model.eval()

num_correct = 0.0
num_pixels = 0.0

m = len(val_x)
_, h, w, _ = ground.shape

with torch.no_grad():
    for i in range(m):

        input = torch.from_numpy(val_x[i]).float()
        input = torch.unsqueeze(input, axis = 0)
        input = input.to(device)

        # # changing from 1 x 96 x 192 x 3 to 1 x 3 x 96 x 192
        input = input.transpose(1, 3)
        input = input.transpose(2, 3)

        # 1 x 1 x 96 x 192
        output = torch.from_numpy(val_ground[i]).float()
        output = torch.unsqueeze(output, axis = 0)
        output = output.to(device)

        output = output.transpose(1, 3)
        output = output.transpose(2, 3)
        output = output[:, 0:1, :, :]

        predictions = model(input)

        loss = dice_loss(predictions, output)
        validation_losses.append(loss.item())

        predictions = torch.where(predictions >= 0.5, 1, 0)

        num_correct = (predictions == output).type(torch.float).sum().item()
        num_pixels = (float) (h*w)

        validation_accuracy.append((num_correct / num_pixels))

        print("# of White : " + str((output != 0).sum().item()) + ", # of Black : " + str((output == 0).sum().item()))
        print("Correctly Predicted : " + str(num_correct) + ", Wrongly Predicted : " + str(num_pixels - num_correct))

        print("Accuracy for validation Sample " + str(i) + " is :" + str(num_correct / num_pixels))
# Out:
# # of White : 264, # of Black : 18168
# Correctly Predicted : 18261.0, Wrongly Predicted : 171.0
# Accuracy for validation Sample 0 is :0.99072265625
# # of White : 307, # of Black : 18125
# Correctly Predicted : 18252.0, Wrongly Predicted : 180.0
# Accuracy for validation Sample 1 is :0.990234375
# # of White : 258, # of Black : 18174
# Correctly Predicted : 18303.0, Wrongly Predicted : 129.0
# Accuracy for validation Sample 2 is :0.9930013020833334
# # of White : 282, # of Black : 18150
# Correctly Predicted : 18290.0, Wrongly Predicted : 142.0
# Accuracy for validation Sample 3 is :0.9922960069444444
# # of White : 287, # of Black : 18145
# Correctly Predicted : 18314.0, Wrongly Predicted : 118.0
# Accuracy for validation Sample 4 is :0.9935980902777778
# # of White : 294, # of Black : 18138
# Correctly Predicted : 18182.0, Wrongly Predicted : 250.0
# Accuracy for validation Sample 5 is :0.9864366319444444
# # of White : 242, # of Black : 18190
# Correctly Predicted : 18242.0, Wrongly Predicted : 190.0
# Accuracy for validation Sample 6 is :0.9896918402777778
# # of White : 248, # of Black : 18184
# Correctly Predicted : 18266.0, Wrongly Predicted : 166.0
# Accuracy for validation Sample 7 is :0.9909939236111112
# # of White : 283, # of Black : 18149
# Correctly Predicted : 18292.0, Wrongly Predicted : 140.0
# Accuracy for validation Sample 8 is :0.9924045138888888
# # of White : 286, # of Black : 18146
# Correctly Predicted : 18314.0, Wrongly Predicted : 118.0
# Accuracy for validation Sample 9 is :0.9935980902777778
# # of White : 266, # of Black : 18166
# Correctly Predicted : 18253.0, Wrongly Predicted : 179.0
# Accuracy for validation Sample 10 is :0.9902886284722222
# # of White : 231, # of Black : 18201
# Correctly Predicted : 18327.0, Wrongly Predicted : 105.0
# Accuracy for validation Sample 11 is :0.9943033854166666
# # of White : 253, # of Black : 18179
# Correctly Predicted : 18350.0, Wrongly Predicted : 82.0
# Accuracy for validation Sample 12 is :0.9955512152777778
# # of White : 279, # of Black : 18153
# Correctly Predicted : 18226.0, Wrongly Predicted : 206.0
# Accuracy for validation Sample 13 is :0.9888237847222222
# # of White : 230, # of Black : 18202
# Correctly Predicted : 18315.0, Wrongly Predicted : 117.0
# Accuracy for validation Sample 14 is :0.99365234375
# # of White : 253, # of Black : 18179
# Correctly Predicted : 18332.0, Wrongly Predicted : 100.0
# Accuracy for validation Sample 15 is :0.9945746527777778
# # of White : 232, # of Black : 18200
# Correctly Predicted : 18331.0, Wrongly Predicted : 101.0
# Accuracy for validation Sample 16 is :0.9945203993055556
# # of White : 263, # of Black : 18169
# Correctly Predicted : 18240.0, Wrongly Predicted : 192.0
# Accuracy for validation Sample 17 is :0.9895833333333334
# # of White : 258, # of Black : 18174
# Correctly Predicted : 18272.0, Wrongly Predicted : 160.0
# Accuracy for validation Sample 18 is :0.9913194444444444
# # of White : 240, # of Black : 18192
# Correctly Predicted : 18234.0, Wrongly Predicted : 198.0
# Accuracy for validation Sample 19 is :0.9892578125
# # of White : 219, # of Black : 18213
# Correctly Predicted : 18257.0, Wrongly Predicted : 175.0
# Accuracy for validation Sample 20 is :0.9905056423611112
# # of White : 264, # of Black : 18168
# Correctly Predicted : 18259.0, Wrongly Predicted : 173.0
# Accuracy for validation Sample 21 is :0.9906141493055556
# # of White : 268, # of Black : 18164
# Correctly Predicted : 18341.0, Wrongly Predicted : 91.0
# Accuracy for validation Sample 22 is :0.9950629340277778
# # of White : 291, # of Black : 18141
# Correctly Predicted : 18267.0, Wrongly Predicted : 165.0
# Accuracy for validation Sample 23 is :0.9910481770833334
# # of White : 230, # of Black : 18202
# Correctly Predicted : 18276.0, Wrongly Predicted : 156.0
# Accuracy for validation Sample 24 is :0.9915364583333334
# # of White : 275, # of Black : 18157
# Correctly Predicted : 18314.0, Wrongly Predicted : 118.0
# Accuracy for validation Sample 25 is :0.9935980902777778
# # of White : 278, # of Black : 18154
# Correctly Predicted : 18258.0, Wrongly Predicted : 174.0
# Accuracy for validation Sample 26 is :0.9905598958333334
# # of White : 243, # of Black : 18189
# Correctly Predicted : 18280.0, Wrongly Predicted : 152.0
# Accuracy for validation Sample 27 is :0.9917534722222222
# # of White : 246, # of Black : 18186
# Correctly Predicted : 18292.0, Wrongly Predicted : 140.0
# Accuracy for validation Sample 28 is :0.9924045138888888
# # of White : 244, # of Black : 18188
# Correctly Predicted : 18241.0, Wrongly Predicted : 191.0
# Accuracy for validation Sample 29 is :0.9896375868055556
# # of White : 221, # of Black : 18211
# Correctly Predicted : 18268.0, Wrongly Predicted : 164.0
# Accuracy for validation Sample 30 is :0.9911024305555556
# # of White : 307, # of Black : 18125
# Correctly Predicted : 18192.0, Wrongly Predicted : 240.0
# Accuracy for validation Sample 31 is :0.9869791666666666
# # of White : 285, # of Black : 18147
# Correctly Predicted : 18231.0, Wrongly Predicted : 201.0
# Accuracy for validation Sample 32 is :0.9890950520833334
# # of White : 257, # of Black : 18175
# Correctly Predicted : 18242.0, Wrongly Predicted : 190.0
# Accuracy for validation Sample 33 is :0.9896918402777778
# # of White : 283, # of Black : 18149
# Correctly Predicted : 18265.0, Wrongly Predicted : 167.0
# Accuracy for validation Sample 34 is :0.9909396701388888
# # of White : 283, # of Black : 18149
# Correctly Predicted : 18234.0, Wrongly Predicted : 198.0
# Accuracy for validation Sample 35 is :0.9892578125
# # of White : 275, # of Black : 18157
# Correctly Predicted : 18309.0, Wrongly Predicted : 123.0
# Accuracy for validation Sample 36 is :0.9933268229166666
# # of White : 297, # of Black : 18135
# Correctly Predicted : 18212.0, Wrongly Predicted : 220.0
# Accuracy for validation Sample 37 is :0.9880642361111112
# # of White : 281, # of Black : 18151
# Correctly Predicted : 18291.0, Wrongly Predicted : 141.0
# Accuracy for validation Sample 38 is :0.9923502604166666
# # of White : 270, # of Black : 18162
# Correctly Predicted : 18313.0, Wrongly Predicted : 119.0
# Accuracy for validation Sample 39 is :0.9935438368055556
# # of White : 250, # of Black : 18182
# Correctly Predicted : 18268.0, Wrongly Predicted : 164.0
# Accuracy for validation Sample 40 is :0.9911024305555556
# # of White : 243, # of Black : 18189
# Correctly Predicted : 18276.0, Wrongly Predicted : 156.0
# Accuracy for validation Sample 41 is :0.9915364583333334
# # of White : 252, # of Black : 18180
# Correctly Predicted : 18318.0, Wrongly Predicted : 114.0
# Accuracy for validation Sample 42 is :0.9938151041666666
# # of White : 274, # of Black : 18158
# Correctly Predicted : 18209.0, Wrongly Predicted : 223.0
# Accuracy for validation Sample 43 is :0.9879014756944444
# # of White : 251, # of Black : 18181
# Correctly Predicted : 18223.0, Wrongly Predicted : 209.0
# Accuracy for validation Sample 44 is :0.9886610243055556
# # of White : 224, # of Black : 18208
# Correctly Predicted : 18257.0, Wrongly Predicted : 175.0
# Accuracy for validation Sample 45 is :0.9905056423611112
# # of White : 252, # of Black : 18180
# Correctly Predicted : 18280.0, Wrongly Predicted : 152.0
# Accuracy for validation Sample 46 is :0.9917534722222222
# # of White : 276, # of Black : 18156
# Correctly Predicted : 18293.0, Wrongly Predicted : 139.0
# Accuracy for validation Sample 47 is :0.9924587673611112
# # of White : 290, # of Black : 18142
# Correctly Predicted : 18203.0, Wrongly Predicted : 229.0
# Accuracy for validation Sample 48 is :0.9875759548611112
# # of White : 271, # of Black : 18161
# Correctly Predicted : 18245.0, Wrongly Predicted : 187.0
# Accuracy for validation Sample 49 is :0.9898546006944444
# # of White : 298, # of Black : 18134
# Correctly Predicted : 18307.0, Wrongly Predicted : 125.0
# Accuracy for validation Sample 50 is :0.9932183159722222
# # of White : 288, # of Black : 18144
# Correctly Predicted : 18214.0, Wrongly Predicted : 218.0
# Accuracy for validation Sample 51 is :0.9881727430555556
# # of White : 298, # of Black : 18134
# Correctly Predicted : 18299.0, Wrongly Predicted : 133.0
# Accuracy for validation Sample 52 is :0.9927842881944444
# # of White : 261, # of Black : 18171
# Correctly Predicted : 18305.0, Wrongly Predicted : 127.0
# Accuracy for validation Sample 53 is :0.9931098090277778
# # of White : 271, # of Black : 18161
# Correctly Predicted : 18267.0, Wrongly Predicted : 165.0
# Accuracy for validation Sample 54 is :0.9910481770833334
# # of White : 227, # of Black : 18205
# Correctly Predicted : 18303.0, Wrongly Predicted : 129.0
# Accuracy for validation Sample 55 is :0.9930013020833334
# # of White : 296, # of Black : 18136
# Correctly Predicted : 18284.0, Wrongly Predicted : 148.0
# Accuracy for validation Sample 56 is :0.9919704861111112
# # of White : 301, # of Black : 18131
# Correctly Predicted : 18298.0, Wrongly Predicted : 134.0
# Accuracy for validation Sample 57 is :0.9927300347222222
# # of White : 253, # of Black : 18179
# Correctly Predicted : 18325.0, Wrongly Predicted : 107.0
# Accuracy for validation Sample 58 is :0.9941948784722222
# # of White : 303, # of Black : 18129
# Correctly Predicted : 18274.0, Wrongly Predicted : 158.0
# Accuracy for validation Sample 59 is :0.9914279513888888
# # of White : 308, # of Black : 18124
# Correctly Predicted : 18256.0, Wrongly Predicted : 176.0
# Accuracy for validation Sample 60 is :0.9904513888888888
# # of White : 303, # of Black : 18129
# Correctly Predicted : 18279.0, Wrongly Predicted : 153.0
# Accuracy for validation Sample 61 is :0.99169921875
# # of White : 290, # of Black : 18142
# Correctly Predicted : 18268.0, Wrongly Predicted : 164.0
# Accuracy for validation Sample 62 is :0.9911024305555556
# # of White : 304, # of Black : 18128
# Correctly Predicted : 18238.0, Wrongly Predicted : 194.0
# Accuracy for validation Sample 63 is :0.9894748263888888
# # of White : 289, # of Black : 18143
# Correctly Predicted : 18225.0, Wrongly Predicted : 207.0
# Accuracy for validation Sample 64 is :0.98876953125
# # of White : 268, # of Black : 18164
# Correctly Predicted : 18298.0, Wrongly Predicted : 134.0
# Accuracy for validation Sample 65 is :0.9927300347222222
# # of White : 274, # of Black : 18158
# Correctly Predicted : 18306.0, Wrongly Predicted : 126.0
# Accuracy for validation Sample 66 is :0.9931640625
# # of White : 271, # of Black : 18161
# Correctly Predicted : 18332.0, Wrongly Predicted : 100.0
# Accuracy for validation Sample 67 is :0.9945746527777778
# # of White : 248, # of Black : 18184
# Correctly Predicted : 18189.0, Wrongly Predicted : 243.0
# Accuracy for validation Sample 68 is :0.98681640625
# # of White : 284, # of Black : 18148
# Correctly Predicted : 18272.0, Wrongly Predicted : 160.0
# Accuracy for validation Sample 69 is :0.9913194444444444
# # of White : 249, # of Black : 18183
# Correctly Predicted : 18337.0, Wrongly Predicted : 95.0
# Accuracy for validation Sample 70 is :0.9948459201388888
# # of White : 267, # of Black : 18165
# Correctly Predicted : 18301.0, Wrongly Predicted : 131.0
# Accuracy for validation Sample 71 is :0.9928927951388888
# # of White : 264, # of Black : 18168
# Correctly Predicted : 18275.0, Wrongly Predicted : 157.0
# Accuracy for validation Sample 72 is :0.9914822048611112
# # of White : 185, # of Black : 18247
# Correctly Predicted : 18287.0, Wrongly Predicted : 145.0
# Accuracy for validation Sample 73 is :0.9921332465277778
# # of White : 284, # of Black : 18148
# Correctly Predicted : 18232.0, Wrongly Predicted : 200.0
# Accuracy for validation Sample 74 is :0.9891493055555556
# # of White : 307, # of Black : 18125
# Correctly Predicted : 18267.0, Wrongly Predicted : 165.0
# Accuracy for validation Sample 75 is :0.9910481770833334
# # of White : 248, # of Black : 18184
# Correctly Predicted : 18329.0, Wrongly Predicted : 103.0
# Accuracy for validation Sample 76 is :0.9944118923611112
# # of White : 273, # of Black : 18159
# Correctly Predicted : 18256.0, Wrongly Predicted : 176.0
# Accuracy for validation Sample 77 is :0.9904513888888888
# # of White : 242, # of Black : 18190
# Correctly Predicted : 18308.0, Wrongly Predicted : 124.0
# Accuracy for validation Sample 78 is :0.9932725694444444
# # of White : 263, # of Black : 18169
# Correctly Predicted : 18315.0, Wrongly Predicted : 117.0
# Accuracy for validation Sample 79 is :0.99365234375
# # of White : 308, # of Black : 18124
# Correctly Predicted : 18283.0, Wrongly Predicted : 149.0
# Accuracy for validation Sample 80 is :0.9919162326388888
# # of White : 253, # of Black : 18179
# Correctly Predicted : 18300.0, Wrongly Predicted : 132.0
# Accuracy for validation Sample 81 is :0.9928385416666666
# # of White : 303, # of Black : 18129
# Correctly Predicted : 18282.0, Wrongly Predicted : 150.0
# Accuracy for validation Sample 82 is :0.9918619791666666
# # of White : 267, # of Black : 18165
# Correctly Predicted : 18275.0, Wrongly Predicted : 157.0
# Accuracy for validation Sample 83 is :0.9914822048611112
# # of White : 289, # of Black : 18143
# Correctly Predicted : 18223.0, Wrongly Predicted : 209.0
# Accuracy for validation Sample 84 is :0.9886610243055556
# # of White : 255, # of Black : 18177
# Correctly Predicted : 18308.0, Wrongly Predicted : 124.0
# Accuracy for validation Sample 85 is :0.9932725694444444
# # of White : 289, # of Black : 18143
# Correctly Predicted : 18298.0, Wrongly Predicted : 134.0
# Accuracy for validation Sample 86 is :0.9927300347222222
# # of White : 284, # of Black : 18148
# Correctly Predicted : 18302.0, Wrongly Predicted : 130.0
# Accuracy for validation Sample 87 is :0.9929470486111112
# # of White : 284, # of Black : 18148
# Correctly Predicted : 18257.0, Wrongly Predicted : 175.0
# Accuracy for validation Sample 88 is :0.9905056423611112
# # of White : 233, # of Black : 18199
# Correctly Predicted : 18329.0, Wrongly Predicted : 103.0
# Accuracy for validation Sample 89 is :0.9944118923611112
# # of White : 312, # of Black : 18120
# Correctly Predicted : 18287.0, Wrongly Predicted : 145.0
# Accuracy for validation Sample 90 is :0.9921332465277778
# # of White : 302, # of Black : 18130
# Correctly Predicted : 18268.0, Wrongly Predicted : 164.0
# Accuracy for validation Sample 91 is :0.9911024305555556
# # of White : 290, # of Black : 18142
# Correctly Predicted : 18272.0, Wrongly Predicted : 160.0
# Accuracy for validation Sample 92 is :0.9913194444444444
# # of White : 249, # of Black : 18183
# Correctly Predicted : 18267.0, Wrongly Predicted : 165.0
# Accuracy for validation Sample 93 is :0.9910481770833334
# # of White : 246, # of Black : 18186
# Correctly Predicted : 18274.0, Wrongly Predicted : 158.0
# Accuracy for validation Sample 94 is :0.9914279513888888
# # of White : 250, # of Black : 18182
# Correctly Predicted : 18309.0, Wrongly Predicted : 123.0
# Accuracy for validation Sample 95 is :0.9933268229166666
# # of White : 285, # of Black : 18147
# Correctly Predicted : 18288.0, Wrongly Predicted : 144.0
# Accuracy for validation Sample 96 is :0.9921875
# # of White : 277, # of Black : 18155
# Correctly Predicted : 18220.0, Wrongly Predicted : 212.0
# Accuracy for validation Sample 97 is :0.9884982638888888
# # of White : 303, # of Black : 18129
# Correctly Predicted : 18296.0, Wrongly Predicted : 136.0
# Accuracy for validation Sample 98 is :0.9926215277777778
# # of White : 206, # of Black : 18226
# Correctly Predicted : 18378.0, Wrongly Predicted : 54.0
# Accuracy for validation Sample 99 is :0.9970703125
# # of White : 295, # of Black : 18137
# Correctly Predicted : 18327.0, Wrongly Predicted : 105.0
# Accuracy for validation Sample 100 is :0.9943033854166666
# # of White : 309, # of Black : 18123
# Correctly Predicted : 18240.0, Wrongly Predicted : 192.0
# Accuracy for validation Sample 101 is :0.9895833333333334
# # of White : 264, # of Black : 18168
# Correctly Predicted : 18239.0, Wrongly Predicted : 193.0
# Accuracy for validation Sample 102 is :0.9895290798611112
# # of White : 293, # of Black : 18139
# Correctly Predicted : 18287.0, Wrongly Predicted : 145.0
# Accuracy for validation Sample 103 is :0.9921332465277778
# # of White : 268, # of Black : 18164
# Correctly Predicted : 18281.0, Wrongly Predicted : 151.0
# Accuracy for validation Sample 104 is :0.9918077256944444
# # of White : 267, # of Black : 18165
# Correctly Predicted : 18326.0, Wrongly Predicted : 106.0
# Accuracy for validation Sample 105 is :0.9942491319444444
# # of White : 247, # of Black : 18185
# Correctly Predicted : 18268.0, Wrongly Predicted : 164.0
# Accuracy for validation Sample 106 is :0.9911024305555556
# # of White : 279, # of Black : 18153
# Correctly Predicted : 18283.0, Wrongly Predicted : 149.0
# Accuracy for validation Sample 107 is :0.9919162326388888
# # of White : 294, # of Black : 18138
# Correctly Predicted : 18260.0, Wrongly Predicted : 172.0
# Accuracy for validation Sample 108 is :0.9906684027777778
# # of White : 304, # of Black : 18128
# Correctly Predicted : 18262.0, Wrongly Predicted : 170.0
# Accuracy for validation Sample 109 is :0.9907769097222222
# # of White : 319, # of Black : 18113
# Correctly Predicted : 18202.0, Wrongly Predicted : 230.0
# Accuracy for validation Sample 110 is :0.9875217013888888
# # of White : 284, # of Black : 18148
# Correctly Predicted : 18257.0, Wrongly Predicted : 175.0
# Accuracy for validation Sample 111 is :0.9905056423611112
# # of White : 268, # of Black : 18164
# Correctly Predicted : 18293.0, Wrongly Predicted : 139.0
# Accuracy for validation Sample 112 is :0.9924587673611112
# # of White : 271, # of Black : 18161
# Correctly Predicted : 18304.0, Wrongly Predicted : 128.0
# Accuracy for validation Sample 113 is :0.9930555555555556
# # of White : 265, # of Black : 18167
# Correctly Predicted : 18278.0, Wrongly Predicted : 154.0
# Accuracy for validation Sample 114 is :0.9916449652777778
# # of White : 276, # of Black : 18156
# Correctly Predicted : 18224.0, Wrongly Predicted : 208.0
# Accuracy for validation Sample 115 is :0.9887152777777778
# # of White : 255, # of Black : 18177
# Correctly Predicted : 18246.0, Wrongly Predicted : 186.0
# Accuracy for validation Sample 116 is :0.9899088541666666
# # of White : 243, # of Black : 18189
# Correctly Predicted : 18310.0, Wrongly Predicted : 122.0
# Accuracy for validation Sample 117 is :0.9933810763888888
# # of White : 264, # of Black : 18168
# Correctly Predicted : 18190.0, Wrongly Predicted : 242.0
# Accuracy for validation Sample 118 is :0.9868706597222222
# # of White : 275, # of Black : 18157
# Correctly Predicted : 18297.0, Wrongly Predicted : 135.0
# Accuracy for validation Sample 119 is :0.99267578125
# # of White : 246, # of Black : 18186
# Correctly Predicted : 18266.0, Wrongly Predicted : 166.0
# Accuracy for validation Sample 120 is :0.9909939236111112
# # of White : 287, # of Black : 18145
# Correctly Predicted : 18235.0, Wrongly Predicted : 197.0
# Accuracy for validation Sample 121 is :0.9893120659722222
# # of White : 281, # of Black : 18151
# Correctly Predicted : 18272.0, Wrongly Predicted : 160.0
# Accuracy for validation Sample 122 is :0.9913194444444444
# # of White : 271, # of Black : 18161
# Correctly Predicted : 18308.0, Wrongly Predicted : 124.0
# Accuracy for validation Sample 123 is :0.9932725694444444
# # of White : 256, # of Black : 18176
# Correctly Predicted : 18239.0, Wrongly Predicted : 193.0
# Accuracy for validation Sample 124 is :0.9895290798611112
# # of White : 266, # of Black : 18166
# Correctly Predicted : 18163.0, Wrongly Predicted : 269.0
# Accuracy for validation Sample 125 is :0.9854058159722222
# # of White : 272, # of Black : 18160
# Correctly Predicted : 18253.0, Wrongly Predicted : 179.0
# Accuracy for validation Sample 126 is :0.9902886284722222
# # of White : 240, # of Black : 18192
# Correctly Predicted : 18307.0, Wrongly Predicted : 125.0
# Accuracy for validation Sample 127 is :0.9932183159722222
# # of White : 308, # of Black : 18124
# Correctly Predicted : 18247.0, Wrongly Predicted : 185.0
# Accuracy for validation Sample 128 is :0.9899631076388888

# %% [markdown]
# ##### Results

# %%
plt.title(f"Loss over the training")
plt.plot(train_losses)
plt.show()

# %%
print("Validation Loss : " + str(sum(validation_losses)/len(validation_losses)))
# Out:
# Validation Loss : 1.050115665724111

# %%
print("Validation Accuracy : " + str(sum(validation_accuracy)/len(validation_accuracy)))
# Out:
# Validation Accuracy : 0.9914237456933679

# %% [markdown]
# # Ouput Visualisation

# %%
sample_number = np.random.randint(129)

# %% [markdown]
# #### Sample Case :

# %%
with torch.no_grad():
    input = torch.from_numpy(val_x[sample_number]).float()
    input = torch.unsqueeze(input, axis = 0)
    input = input.to(device)

    # # changing from 10 x 96 x 192 x 3 to 10 x 3 x 96 x 192
    input = input.transpose(1, 3)
    input = input.transpose(2, 3)

    # 10 x 1 x 96 x 192
    output = torch.from_numpy(val_ground[sample_number]).float()
    output = torch.unsqueeze(output, axis = 0)
    output = output.to(device)

    output = output.transpose(1, 3)
    output = output.transpose(2, 3)

    predictions = model(input)
    predictions = torch.where(predictions >= 0.5, 1, 0)

    num_correct = (predictions == output).type(torch.float).sum().item()
    num_pixels = (float) (h*w)

    print("# of White : " + str((output != 0).sum().item()) + ", # of Black : " + str((output == 0).sum().item()))
    print("Correctly Predicted : " + str(num_correct) + ", Wrongly Predicted : " + str(num_pixels - num_correct))

    print("Accuracy for validation Sample " + str(i) + " is :" + str(num_correct / num_pixels))
# Out:
# # of White : 286, # of Black : 18146
# Correctly Predicted : 18314.0, Wrongly Predicted : 118.0
# Accuracy for validation Sample 128 is :0.9935980902777778

# %% [markdown]
# #### Visuals

# %%
broad_caster = np.ones(shape=(96, 192, 3))

# %%
with torch.no_grad():
    ip = torch.from_numpy(val_x[sample_number]).float()
    ip = torch.unsqueeze(ip, axis = 0)
    ip = ip.to(device)
    # # changing from 10 x 96 x 192 x 3 to 10 x 3 x 96 x 192
    ip = ip.transpose(1, 3)
    ip = ip.transpose(2, 3)

    y_pred = model(ip)

    y_pred = y_pred[0]

    y_pred = y_pred.transpose(0, 1)
    y_pred = y_pred.transpose(1, 2)

    y_pred = y_pred.cpu()
    y_pred = y_pred.numpy()

    plt.figure()
    f, axarr = plt.subplots(2,2, figsize=(17, 12)) 

    t = np.where(y_pred >= 0.5, y_pred, 0)

    axarr[0][0].title.set_text("Input Image")
    axarr[0][0].imshow(val_x[sample_number])

    axarr[0][1].title.set_text("Model Output Image")
    axarr[0][1].imshow(y_pred*broad_caster)

    axarr[1][0].title.set_text("Ground Truth")
    axarr[1][0].imshow(val_ground[sample_number]*broad_caster*100)
    
    axarr[1][1].title.set_text("Processed Output Image")
    axarr[1][1].imshow(t * broad_caster * 100)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
