# %% [markdown]
# # Libraries

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import torchvision.transforms as transforms
import torchvision.transforms.functional as TF

# colab libraries
from google.colab import drive
from google.colab.patches import cv2_imshow

import os
import cv2
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from tqdm import tqdm

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Seeding

# %%
torch.manual_seed(784)

# %%
np.random.seed(54)

# %% [markdown]
# # Data Processing

# %% [markdown]
# ## Mount Drive

# %%
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
BASE_PATH = '/content/drive/MyDrive/DL Project/Project Dataset'
TRAIN_PATH = BASE_PATH + '/train_unzipped'
TRAIN_LABEL_PATH = BASE_PATH + '/train_label_unzipped'
VAL_PATH = BASE_PATH + '/val_unzipped'
VAL_LABEL_PATH = BASE_PATH + '/val_label_unzipped'

# %% [markdown]
# ## Load Data

# %%
def import_data(INPUT_PATH: str, LABEL_PATH: str, final_dimension: tuple, input_id_index : tuple, label_id_index : tuple, is_val: bool = False):

    inputs = []
    labels = []

    files = os.listdir(INPUT_PATH)
    label_files = os.listdir(LABEL_PATH)

    for index, file in enumerate(files):
        
        if (not is_val) and index % 3 > 0:
            continue

        try:
            idx = (int) (file[ input_id_index[0] : input_id_index[1] ])
        except:
            continue

        image = cv2.imread(INPUT_PATH+"/"+file)
        image = cv2.resize(image, final_dimension)
        inputs.append(image)

        for label_file in label_files:
        
            label_idx = (int)(label_file[ label_id_index[0] : label_id_index[1] ])

            if(idx == label_idx):
                label_image = cv2.imread(LABEL_PATH+"/"+label_file)
                label_image = cv2.resize(label_image, final_dimension)
                labels.append(label_image)
                break

    inputs = np.array(inputs)
    inputs = inputs/255
    labels = np.array(labels)
    labels = labels/255

    return (inputs, labels)

# %%
reduced_dims = (192, 96)

# %%
# the below 4 variables denotes the idx indices for the file names

train_input_id_index = (44, -4)   # Example: Town04_Clear_Noon_09_09_2020_14_57_22_frame_0.png
train_label_id_index = (44, -10)  # Example: Town04_Clear_Noon_09_09_2020_14_57_22_frame_0_label.png

val_input_id_index = (44, -19)    # Example: Town04_Clear_Noon_09_09_2020_14_57_22_frame_100_validation_set.png
val_label_id_index = (44, -25)    # Example: Town04_Clear_Noon_09_09_2020_14_57_22_frame_100_validation_set_label.png

# %%
train_x, train_y = import_data(TRAIN_PATH, TRAIN_LABEL_PATH, reduced_dims, train_input_id_index, train_label_id_index)
val_x, val_y = import_data(VAL_PATH, VAL_LABEL_PATH, reduced_dims, val_input_id_index, val_label_id_index, True)

# %%
print(train_x.shape, train_y.shape)
print(val_x.shape, val_y.shape)
# Out:
# (1026, 96, 192, 3) (1026, 96, 192, 3)
# (129, 96, 192, 3) (129, 96, 192, 3)

# %% [markdown]
# ## Data Visualising

# %%
i = np.random.randint(0, len(train_x))
plt.imshow(train_x[i])
plt.title(f"Training example #{i}")
plt.show()
plt.imshow(train_y[i]*100)
plt.show()

# %% [markdown]
# # Model Architecture

# %%
class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(DoubleConv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, 1, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, 3, 1, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):
        return self.conv(x)

class UNET(nn.Module):
    def __init__(
            self, in_channels=3, out_channels=1, features=[32, 64, 128, 256],
    ):
        super(UNET, self).__init__()
        self.ups = nn.ModuleList()
        self.downs = nn.ModuleList()
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.sigmoid = nn.Sigmoid()

        # Down part of UNET
        for feature in features:
            self.downs.append(DoubleConv(in_channels, feature))
            in_channels = feature

        # Up part of UNET
        for feature in reversed(features):
            self.ups.append(
                nn.ConvTranspose2d(
                    feature*2, feature, kernel_size=2, stride=2,
                )
            )
            self.ups.append(DoubleConv(feature*2, feature))

        self.bottleneck = DoubleConv(features[-1], features[-1]*2)
        self.final_conv = nn.Conv2d(features[0], out_channels, kernel_size=1)

    def forward(self, x):
        skip_connections = []

        for down in self.downs:
            x = down(x)
            skip_connections.append(x)
            x = self.pool(x)

        x = self.bottleneck(x)
        skip_connections = skip_connections[::-1]

        for idx in range(0, len(self.ups), 2):
            x = self.ups[idx](x)
            skip_connection = skip_connections[idx//2]

            if x.shape != skip_connection.shape:
                x = TF.resize(x, size=skip_connection.shape[2:])

            concat_skip = torch.cat((skip_connection, x), dim=1)
            x = self.ups[idx+1](concat_skip)
        x = self.final_conv(x)
        return self.sigmoid(x)

# %% [markdown]
# #### Model Summary

# %%
input_dim = (3, 96, 192)

# %%
from torchsummary import summary
testing_model = UNET()

# while working on GPU
summary(testing_model.cuda(), input_dim)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 32, 96, 192]             864
#        BatchNorm2d-2          [-1, 32, 96, 192]              64
#               ReLU-3          [-1, 32, 96, 192]               0
#             Conv2d-4          [-1, 32, 96, 192]           9,216
#        BatchNorm2d-5          [-1, 32, 96, 192]              64
#               ReLU-6          [-1, 32, 96, 192]               0
#         DoubleConv-7          [-1, 32, 96, 192]               0
#          MaxPool2d-8           [-1, 32, 48, 96]               0
#             Conv2d-9           [-1, 64, 48, 96]          18,432
#       BatchNorm2d-10           [-1, 64, 48, 96]             128
#              ReLU-11           [-1, 64, 48, 96]               0
#            Conv2d-12           [-1, 64, 48, 96]          36,864
#       BatchNorm2d-13           [-1, 64, 48, 96]             128
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.21
# Forward/backward pass size (MB): 130.92
# Params size (MB): 29.61
# Estimated Total Size (MB): 160.75
# ----------------------------------------------------------------

# %% [markdown]
# # Ground

# %% [markdown]
# ## Train Preprocessing

# %%
n, h, w, c = train_y.shape          # 1026 x 96 x 192 x 3
shape_ground = (n, h, w, 1)

# %%
ground = np.zeros(shape=shape_ground)   # 1026 x 96 x 192 x 1
back_ground_limit = 0.0

# %%
def get_ground_for_each_train(y_train):
    n, h, w, c = y_train.shape          # 1026 x 96 x 192 x 3
    for i in range(n):
        ground[i] = np.where(np.mean(y_train[i], axis=2, keepdims=True) <= back_ground_limit, 0, 1)
    return

# %%
get_ground_for_each_train(train_y)

# %%
ground.shape
# Out:
# (1026, 96, 192, 1)

# %% [markdown]
# ##### Train Ground Visual

# %%
broad_caster = broad_caster = np.ones(shape=(96, 192, 3))

# %%
i = np.random.randint(0, len(train_y))
plt.imshow(train_y[i]*100)
plt.title(f"Training example #{i}")
plt.show()
plt.imshow(ground[i]*broad_caster*100)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Validation Preprocessing

# %%
n, h, w, c = val_y.shape          # 1026 x 96 x 192 x 3
shape_val = (n, h, w, 1)

# %%
val_ground = np.zeros(shape=shape_val)

# %%
def get_ground_for_each_val(y_test):
    n, h, w, c = y_test.shape          # 1026 x 96 x 192 x 3
    for i in range(n):
        val_ground[i] = np.where(np.mean(y_test[i], axis=2, keepdims=True) <= back_ground_limit, 0, 1)
    return

# %%
get_ground_for_each_val(val_y)

# %%
val_ground.shape
# Out:
# (129, 96, 192, 1)

# %% [markdown]
# # Loss Function

# %% [markdown]
# #### Focal Loss

# %%
import torch.nn.functional as F

class FocalLoss(nn.Module):
    def __init__(self, alpha=0.25, gamma=2, epsilon = 1e-6):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon

    def forward(self, pred, target):
        # batch_size x 1 x 96 x 192
        loss = -target*(torch.log(pred + self.epsilon)*(1-pred)**self.gamma) - (1-target)*(torch.log((1-pred) + self.epsilon)*(pred)**self.gamma)
        return torch.mean(loss)

# %% [markdown]
# # Learning

# %% [markdown]
# #### Hyperparameters

# %%
lr = 0.01
batch_size = 8
momentum = 0.2
epochs = 200
GAMMA = 2

# %% [markdown]
# #### Shapes

# %%
print(train_x.shape , train_y.shape)
# Out:
# (1026, 96, 192, 3) (1026, 96, 192, 3)

# %%
print(val_x.shape, val_y.shape)
# Out:
# (129, 96, 192, 3) (129, 96, 192, 3)

# %%
print(ground.shape)
# Out:
# (1026, 96, 192, 1)

# %%
print(val_ground.shape)
# Out:
# (129, 96, 192, 1)

# %% [markdown]
# #### Model Initialisation

# %%
model = UNET().to(device)

# %% [markdown]
# #### Optimizer

# %%
optimizer = optim.SGD(model.parameters(), lr, momentum)

# %% [markdown]
# #### Loss Class

# %%
focal_loss = FocalLoss(gamma=GAMMA)

# %% [markdown]
# #### Weight Initializer

# %%
def initialize_weights(m):
    if isinstance(m, nn.Conv2d):
        nn.init.normal_(m.weight.data, 0, 1)
        if m.bias is not None:
            nn.init.constant_(m.bias.data, 0)
    elif isinstance(m, nn.BatchNorm2d):
        nn.init.normal_(m.weight.data, 0, 1)
        nn.init.constant_(m.bias.data, 0)
    elif isinstance(m, nn.Linear):
        nn.init.normal_(m.weight.data, 0, 1)
        nn.init.constant_(m.bias.data, 0)

# %% [markdown]
# #### Training and Validation

# %%
train_losses = []
validation_losses = []

# %%
model.train()
model.apply(initialize_weights)

n = len(train_x)

for epoch in range(epochs):

    train_loss = 0.0

    for i in range( n//batch_size ):

        optimizer.zero_grad()

        input = torch.from_numpy(train_x[i*batch_size: i*batch_size+batch_size]).float()
        input = input.to(device)

        # changing from batch_size x 96 x 192 x 3 to batch_size x 3 x 96 x 192
        input = input.transpose(1, 3)
        input = input.transpose(2, 3)

        # batch_size x 96 x 192 x 7
        output = torch.from_numpy(ground[i*batch_size: i*batch_size+batch_size]).float()
        output = output.to(device)

        # changing from batch_size x 96 x 192 x 1 to batch_size x 1 x 96 x 192
        output = output.transpose(1, 3)
        output = output.transpose(2, 3)

        # forward
        predictions = model(input)                  # batch_size x 1 x 96 x 192
        loss = focal_loss(predictions, output)

        # backward
        loss.backward()
        optimizer.step()

        # update losses
        train_loss += loss.item()

    print("Loss after epoch " + str(epoch) + " is : " + str(loss.item()))
    train_losses.append(train_loss)
# Out:
# Loss after epoch 0 is : 0.04822926968336105
# Loss after epoch 1 is : 0.036615196615457535
# Loss after epoch 2 is : 0.032807160168886185
# Loss after epoch 3 is : 0.030510349199175835
# Loss after epoch 4 is : 0.02882598526775837
# Loss after epoch 5 is : 0.027524549514055252
# Loss after epoch 6 is : 0.0264885276556015
# Loss after epoch 7 is : 0.02564321830868721
# Loss after epoch 8 is : 0.024934399873018265
# Loss after epoch 9 is : 0.024323413148522377
# Loss after epoch 10 is : 0.02378891222178936
# Loss after epoch 11 is : 0.02331559546291828
# Loss after epoch 12 is : 0.02289430797100067
# Loss after epoch 13 is : 0.02251543663442135
# Loss after epoch 14 is : 0.022170793265104294
# Loss after epoch 15 is : 0.021852202713489532
# Loss after epoch 16 is : 0.02155795693397522
# Loss after epoch 17 is : 0.021287495270371437
# Loss after epoch 18 is : 0.021036649122834206
# Loss after epoch 19 is : 0.020804651081562042
# Loss after epoch 20 is : 0.02058921940624714
# Loss after epoch 21 is : 0.020388120785355568
# Loss after epoch 22 is : 0.02019917219877243
# Loss after epoch 23 is : 0.020021865144371986
# Loss after epoch 24 is : 0.019856013357639313
# Loss after epoch 25 is : 0.019699519500136375
# Loss after epoch 26 is : 0.01955157145857811
# Loss after epoch 27 is : 0.019411331042647362
# Loss after epoch 28 is : 0.019277747720479965
# Loss after epoch 29 is : 0.019148260354995728
# Loss after epoch 30 is : 0.019024048000574112
# Loss after epoch 31 is : 0.018904468044638634
# Loss after epoch 32 is : 0.018788732588291168
# Loss after epoch 33 is : 0.018677718937397003
# Loss after epoch 34 is : 0.01857070066034794
# Loss after epoch 35 is : 0.018467983230948448
# Loss after epoch 36 is : 0.018369236961007118
# Loss after epoch 37 is : 0.01827387325465679
# Loss after epoch 38 is : 0.018181346356868744
# Loss after epoch 39 is : 0.018091702833771706
# Loss after epoch 40 is : 0.018004871904850006
# Loss after epoch 41 is : 0.01792084239423275
# Loss after epoch 42 is : 0.01783915050327778
# Loss after epoch 43 is : 0.017760025337338448
# Loss after epoch 44 is : 0.017682796344161034
# Loss after epoch 45 is : 0.01760801672935486
# Loss after epoch 46 is : 0.017535289749503136
# Loss after epoch 47 is : 0.017464654520154
# Loss after epoch 48 is : 0.017396463081240654
# Loss after epoch 49 is : 0.01732964627444744
# Loss after epoch 50 is : 0.017264200374484062
# Loss after epoch 51 is : 0.01720031537115574
# Loss after epoch 52 is : 0.017138490453362465
# Loss after epoch 53 is : 0.017078248783946037
# Loss after epoch 54 is : 0.017019126564264297
# Loss after epoch 55 is : 0.016961337998509407
# Loss after epoch 193 is : 0.013212097808718681
# Loss after epoch 194 is : 0.013196622021496296
# Loss after epoch 195 is : 0.013181219808757305
# Loss after epoch 196 is : 0.013165957294404507
# Loss after epoch 197 is : 0.013150814920663834
# Loss after epoch 198 is : 0.013135681860148907
# Loss after epoch 199 is : 0.013120514340698719

# %%
validation_accuracy = []

# %%
model.eval()

num_correct = 0.0
num_pixels = 0.0

m = len(val_x)
_, h, w, _ = ground.shape

with torch.no_grad():
    for i in range(m):

        input = torch.from_numpy(val_x[i]).float()
        input = torch.unsqueeze(input, axis = 0)
        input = input.to(device)

        # # changing from 1 x 96 x 192 x 3 to 1 x 3 x 96 x 192
        input = input.transpose(1, 3)
        input = input.transpose(2, 3)

        # 1 x 1 x 96 x 192
        output = torch.from_numpy(val_ground[i]).float()
        output = torch.unsqueeze(output, axis = 0)
        output = output.to(device)

        output = output.transpose(1, 3)
        output = output.transpose(2, 3)
        output = output[:, 0:1, :, :]

        predictions = model(input)

        loss = focal_loss(predictions, output)
        validation_losses.append(loss.item())

        predictions = torch.where(predictions >= 0.5, 1, 0)

        num_correct = (predictions == output).type(torch.float).sum().item()
        num_pixels = (float) (h*w)

        validation_accuracy.append((num_correct / num_pixels))

        print("# of White : " + str((output != 0).sum().item()) + ", # of Black : " + str((output == 0).sum().item()))
        print("Correctly Predicted : " + str(num_correct) + ", Wrongly Predicted : " + str(num_pixels - num_correct))

        print("Accuracy for validation Sample " + str(i) + " is :" + str(num_correct / num_pixels))
# Out:
# # of White : 264, # of Black : 18168
# Correctly Predicted : 18175.0, Wrongly Predicted : 257.0
# Accuracy for validation Sample 0 is :0.9860568576388888
# # of White : 307, # of Black : 18125
# Correctly Predicted : 18172.0, Wrongly Predicted : 260.0
# Accuracy for validation Sample 1 is :0.9858940972222222
# # of White : 258, # of Black : 18174
# Correctly Predicted : 18213.0, Wrongly Predicted : 219.0
# Accuracy for validation Sample 2 is :0.9881184895833334
# # of White : 282, # of Black : 18150
# Correctly Predicted : 18184.0, Wrongly Predicted : 248.0
# Accuracy for validation Sample 3 is :0.9865451388888888
# # of White : 287, # of Black : 18145
# Correctly Predicted : 18220.0, Wrongly Predicted : 212.0
# Accuracy for validation Sample 4 is :0.9884982638888888
# # of White : 294, # of Black : 18138
# Correctly Predicted : 18142.0, Wrongly Predicted : 290.0
# Accuracy for validation Sample 5 is :0.9842664930555556
# # of White : 242, # of Black : 18190
# Correctly Predicted : 18210.0, Wrongly Predicted : 222.0
# Accuracy for validation Sample 6 is :0.9879557291666666
# # of White : 248, # of Black : 18184
# Correctly Predicted : 18184.0, Wrongly Predicted : 248.0
# Accuracy for validation Sample 7 is :0.9865451388888888
# # of White : 283, # of Black : 18149
# Correctly Predicted : 18201.0, Wrongly Predicted : 231.0
# Accuracy for validation Sample 8 is :0.9874674479166666
# # of White : 286, # of Black : 18146
# Correctly Predicted : 18225.0, Wrongly Predicted : 207.0
# Accuracy for validation Sample 9 is :0.98876953125
# # of White : 266, # of Black : 18166
# Correctly Predicted : 18181.0, Wrongly Predicted : 251.0
# Accuracy for validation Sample 10 is :0.9863823784722222
# # of White : 231, # of Black : 18201
# Correctly Predicted : 18217.0, Wrongly Predicted : 215.0
# Accuracy for validation Sample 11 is :0.9883355034722222
# # of White : 253, # of Black : 18179
# Correctly Predicted : 18241.0, Wrongly Predicted : 191.0
# Accuracy for validation Sample 12 is :0.9896375868055556
# # of White : 279, # of Black : 18153
# Correctly Predicted : 18208.0, Wrongly Predicted : 224.0
# Accuracy for validation Sample 13 is :0.9878472222222222
# # of White : 230, # of Black : 18202
# Correctly Predicted : 18228.0, Wrongly Predicted : 204.0
# Accuracy for validation Sample 14 is :0.9889322916666666
# # of White : 253, # of Black : 18179
# Correctly Predicted : 18221.0, Wrongly Predicted : 211.0
# Accuracy for validation Sample 15 is :0.9885525173611112
# # of White : 232, # of Black : 18200
# Correctly Predicted : 18247.0, Wrongly Predicted : 185.0
# Accuracy for validation Sample 16 is :0.9899631076388888
# # of White : 263, # of Black : 18169
# Correctly Predicted : 18188.0, Wrongly Predicted : 244.0
# Accuracy for validation Sample 17 is :0.9867621527777778
# # of White : 258, # of Black : 18174
# Correctly Predicted : 18197.0, Wrongly Predicted : 235.0
# Accuracy for validation Sample 18 is :0.9872504340277778
# # of White : 240, # of Black : 18192
# Correctly Predicted : 18199.0, Wrongly Predicted : 233.0
# Accuracy for validation Sample 19 is :0.9873589409722222
# # of White : 219, # of Black : 18213
# Correctly Predicted : 18209.0, Wrongly Predicted : 223.0
# Accuracy for validation Sample 20 is :0.9879014756944444
# # of White : 264, # of Black : 18168
# Correctly Predicted : 18182.0, Wrongly Predicted : 250.0
# Accuracy for validation Sample 21 is :0.9864366319444444
# # of White : 268, # of Black : 18164
# Correctly Predicted : 18261.0, Wrongly Predicted : 171.0
# Accuracy for validation Sample 22 is :0.99072265625
# # of White : 291, # of Black : 18141
# Correctly Predicted : 18212.0, Wrongly Predicted : 220.0
# Accuracy for validation Sample 23 is :0.9880642361111112
# # of White : 230, # of Black : 18202
# Correctly Predicted : 18242.0, Wrongly Predicted : 190.0
# Accuracy for validation Sample 24 is :0.9896918402777778
# # of White : 275, # of Black : 18157
# Correctly Predicted : 18204.0, Wrongly Predicted : 228.0
# Accuracy for validation Sample 25 is :0.9876302083333334
# # of White : 278, # of Black : 18154
# Correctly Predicted : 18172.0, Wrongly Predicted : 260.0
# Accuracy for validation Sample 26 is :0.9858940972222222
# # of White : 243, # of Black : 18189
# Correctly Predicted : 18207.0, Wrongly Predicted : 225.0
# Accuracy for validation Sample 27 is :0.98779296875
# # of White : 246, # of Black : 18186
# Correctly Predicted : 18221.0, Wrongly Predicted : 211.0
# Accuracy for validation Sample 28 is :0.9885525173611112
# # of White : 244, # of Black : 18188
# Correctly Predicted : 18210.0, Wrongly Predicted : 222.0
# Accuracy for validation Sample 29 is :0.9879557291666666
# # of White : 221, # of Black : 18211
# Correctly Predicted : 18237.0, Wrongly Predicted : 195.0
# Accuracy for validation Sample 30 is :0.9894205729166666
# # of White : 307, # of Black : 18125
# Correctly Predicted : 18156.0, Wrongly Predicted : 276.0
# Accuracy for validation Sample 31 is :0.9850260416666666
# # of White : 285, # of Black : 18147
# Correctly Predicted : 18161.0, Wrongly Predicted : 271.0
# Accuracy for validation Sample 32 is :0.9852973090277778
# # of White : 257, # of Black : 18175
# Correctly Predicted : 18186.0, Wrongly Predicted : 246.0
# Accuracy for validation Sample 33 is :0.9866536458333334
# # of White : 283, # of Black : 18149
# Correctly Predicted : 18186.0, Wrongly Predicted : 246.0
# Accuracy for validation Sample 34 is :0.9866536458333334
# # of White : 283, # of Black : 18149
# Correctly Predicted : 18178.0, Wrongly Predicted : 254.0
# Accuracy for validation Sample 35 is :0.9862196180555556
# # of White : 275, # of Black : 18157
# Correctly Predicted : 18225.0, Wrongly Predicted : 207.0
# Accuracy for validation Sample 36 is :0.98876953125
# # of White : 297, # of Black : 18135
# Correctly Predicted : 18152.0, Wrongly Predicted : 280.0
# Accuracy for validation Sample 37 is :0.9848090277777778
# # of White : 281, # of Black : 18151
# Correctly Predicted : 18208.0, Wrongly Predicted : 224.0
# Accuracy for validation Sample 38 is :0.9878472222222222
# # of White : 270, # of Black : 18162
# Correctly Predicted : 18206.0, Wrongly Predicted : 226.0
# Accuracy for validation Sample 39 is :0.9877387152777778
# # of White : 250, # of Black : 18182
# Correctly Predicted : 18204.0, Wrongly Predicted : 228.0
# Accuracy for validation Sample 40 is :0.9876302083333334
# # of White : 243, # of Black : 18189
# Correctly Predicted : 18216.0, Wrongly Predicted : 216.0
# Accuracy for validation Sample 41 is :0.98828125
# # of White : 252, # of Black : 18180
# Correctly Predicted : 18217.0, Wrongly Predicted : 215.0
# Accuracy for validation Sample 42 is :0.9883355034722222
# # of White : 274, # of Black : 18158
# Correctly Predicted : 18171.0, Wrongly Predicted : 261.0
# Accuracy for validation Sample 43 is :0.98583984375
# # of White : 251, # of Black : 18181
# Correctly Predicted : 18196.0, Wrongly Predicted : 236.0
# Accuracy for validation Sample 44 is :0.9871961805555556
# # of White : 224, # of Black : 18208
# Correctly Predicted : 18225.0, Wrongly Predicted : 207.0
# Accuracy for validation Sample 45 is :0.98876953125
# # of White : 252, # of Black : 18180
# Correctly Predicted : 18193.0, Wrongly Predicted : 239.0
# Accuracy for validation Sample 46 is :0.9870334201388888
# # of White : 276, # of Black : 18156
# Correctly Predicted : 18195.0, Wrongly Predicted : 237.0
# Accuracy for validation Sample 47 is :0.9871419270833334
# # of White : 290, # of Black : 18142
# Correctly Predicted : 18168.0, Wrongly Predicted : 264.0
# Accuracy for validation Sample 48 is :0.9856770833333334
# # of White : 271, # of Black : 18161
# Correctly Predicted : 18175.0, Wrongly Predicted : 257.0
# Accuracy for validation Sample 49 is :0.9860568576388888
# # of White : 298, # of Black : 18134
# Correctly Predicted : 18230.0, Wrongly Predicted : 202.0
# Accuracy for validation Sample 50 is :0.9890407986111112
# # of White : 288, # of Black : 18144
# Correctly Predicted : 18171.0, Wrongly Predicted : 261.0
# Accuracy for validation Sample 51 is :0.98583984375
# # of White : 298, # of Black : 18134
# Correctly Predicted : 18214.0, Wrongly Predicted : 218.0
# Accuracy for validation Sample 52 is :0.9881727430555556
# # of White : 261, # of Black : 18171
# Correctly Predicted : 18222.0, Wrongly Predicted : 210.0
# Accuracy for validation Sample 53 is :0.9886067708333334
# # of White : 271, # of Black : 18161
# Correctly Predicted : 18191.0, Wrongly Predicted : 241.0
# Accuracy for validation Sample 54 is :0.9869249131944444
# # of White : 227, # of Black : 18205
# Correctly Predicted : 18219.0, Wrongly Predicted : 213.0
# Accuracy for validation Sample 55 is :0.9884440104166666
# # of White : 296, # of Black : 18136
# Correctly Predicted : 18177.0, Wrongly Predicted : 255.0
# Accuracy for validation Sample 56 is :0.9861653645833334
# # of White : 301, # of Black : 18131
# Correctly Predicted : 18233.0, Wrongly Predicted : 199.0
# Accuracy for validation Sample 57 is :0.9892035590277778
# # of White : 253, # of Black : 18179
# Correctly Predicted : 18237.0, Wrongly Predicted : 195.0
# Accuracy for validation Sample 58 is :0.9894205729166666
# # of White : 303, # of Black : 18129
# Correctly Predicted : 18207.0, Wrongly Predicted : 225.0
# Accuracy for validation Sample 59 is :0.98779296875
# # of White : 308, # of Black : 18124
# Correctly Predicted : 18178.0, Wrongly Predicted : 254.0
# Accuracy for validation Sample 60 is :0.9862196180555556
# # of White : 303, # of Black : 18129
# Correctly Predicted : 18196.0, Wrongly Predicted : 236.0
# Accuracy for validation Sample 61 is :0.9871961805555556
# # of White : 290, # of Black : 18142
# Correctly Predicted : 18180.0, Wrongly Predicted : 252.0
# Accuracy for validation Sample 62 is :0.986328125
# # of White : 304, # of Black : 18128
# Correctly Predicted : 18180.0, Wrongly Predicted : 252.0
# Accuracy for validation Sample 63 is :0.986328125
# # of White : 289, # of Black : 18143
# Correctly Predicted : 18175.0, Wrongly Predicted : 257.0
# Accuracy for validation Sample 64 is :0.9860568576388888
# # of White : 268, # of Black : 18164
# Correctly Predicted : 18229.0, Wrongly Predicted : 203.0
# Accuracy for validation Sample 65 is :0.9889865451388888
# # of White : 274, # of Black : 18158
# Correctly Predicted : 18195.0, Wrongly Predicted : 237.0
# Accuracy for validation Sample 66 is :0.9871419270833334
# # of White : 271, # of Black : 18161
# Correctly Predicted : 18243.0, Wrongly Predicted : 189.0
# Accuracy for validation Sample 67 is :0.98974609375
# # of White : 248, # of Black : 18184
# Correctly Predicted : 18180.0, Wrongly Predicted : 252.0
# Accuracy for validation Sample 68 is :0.986328125
# # of White : 284, # of Black : 18148
# Correctly Predicted : 18192.0, Wrongly Predicted : 240.0
# Accuracy for validation Sample 69 is :0.9869791666666666
# # of White : 249, # of Black : 18183
# Correctly Predicted : 18212.0, Wrongly Predicted : 220.0
# Accuracy for validation Sample 70 is :0.9880642361111112
# # of White : 267, # of Black : 18165
# Correctly Predicted : 18230.0, Wrongly Predicted : 202.0
# Accuracy for validation Sample 71 is :0.9890407986111112
# # of White : 264, # of Black : 18168
# Correctly Predicted : 18189.0, Wrongly Predicted : 243.0
# Accuracy for validation Sample 72 is :0.98681640625
# # of White : 185, # of Black : 18247
# Correctly Predicted : 18251.0, Wrongly Predicted : 181.0
# Accuracy for validation Sample 73 is :0.9901801215277778
# # of White : 284, # of Black : 18148
# Correctly Predicted : 18205.0, Wrongly Predicted : 227.0
# Accuracy for validation Sample 74 is :0.9876844618055556
# # of White : 307, # of Black : 18125
# Correctly Predicted : 18200.0, Wrongly Predicted : 232.0
# Accuracy for validation Sample 75 is :0.9874131944444444
# # of White : 248, # of Black : 18184
# Correctly Predicted : 18227.0, Wrongly Predicted : 205.0
# Accuracy for validation Sample 76 is :0.9888780381944444
# # of White : 273, # of Black : 18159
# Correctly Predicted : 18208.0, Wrongly Predicted : 224.0
# Accuracy for validation Sample 77 is :0.9878472222222222
# # of White : 242, # of Black : 18190
# Correctly Predicted : 18227.0, Wrongly Predicted : 205.0
# Accuracy for validation Sample 78 is :0.9888780381944444
# # of White : 263, # of Black : 18169
# Correctly Predicted : 18240.0, Wrongly Predicted : 192.0
# Accuracy for validation Sample 79 is :0.9895833333333334
# # of White : 308, # of Black : 18124
# Correctly Predicted : 18205.0, Wrongly Predicted : 227.0
# Accuracy for validation Sample 80 is :0.9876844618055556
# # of White : 253, # of Black : 18179
# Correctly Predicted : 18239.0, Wrongly Predicted : 193.0
# Accuracy for validation Sample 81 is :0.9895290798611112
# # of White : 303, # of Black : 18129
# Correctly Predicted : 18223.0, Wrongly Predicted : 209.0
# Accuracy for validation Sample 82 is :0.9886610243055556
# # of White : 267, # of Black : 18165
# Correctly Predicted : 18207.0, Wrongly Predicted : 225.0
# Accuracy for validation Sample 83 is :0.98779296875
# # of White : 289, # of Black : 18143
# Correctly Predicted : 18158.0, Wrongly Predicted : 274.0
# Accuracy for validation Sample 84 is :0.9851345486111112
# # of White : 255, # of Black : 18177
# Correctly Predicted : 18218.0, Wrongly Predicted : 214.0
# Accuracy for validation Sample 85 is :0.9883897569444444
# # of White : 289, # of Black : 18143
# Correctly Predicted : 18246.0, Wrongly Predicted : 186.0
# Accuracy for validation Sample 86 is :0.9899088541666666
# # of White : 284, # of Black : 18148
# Correctly Predicted : 18238.0, Wrongly Predicted : 194.0
# Accuracy for validation Sample 87 is :0.9894748263888888
# # of White : 284, # of Black : 18148
# Correctly Predicted : 18206.0, Wrongly Predicted : 226.0
# Accuracy for validation Sample 88 is :0.9877387152777778
# # of White : 233, # of Black : 18199
# Correctly Predicted : 18230.0, Wrongly Predicted : 202.0
# Accuracy for validation Sample 89 is :0.9890407986111112
# # of White : 312, # of Black : 18120
# Correctly Predicted : 18204.0, Wrongly Predicted : 228.0
# Accuracy for validation Sample 90 is :0.9876302083333334
# # of White : 302, # of Black : 18130
# Correctly Predicted : 18210.0, Wrongly Predicted : 222.0
# Accuracy for validation Sample 91 is :0.9879557291666666
# # of White : 290, # of Black : 18142
# Correctly Predicted : 18222.0, Wrongly Predicted : 210.0
# Accuracy for validation Sample 92 is :0.9886067708333334
# # of White : 249, # of Black : 18183
# Correctly Predicted : 18198.0, Wrongly Predicted : 234.0
# Accuracy for validation Sample 93 is :0.9873046875
# # of White : 246, # of Black : 18186
# Correctly Predicted : 18227.0, Wrongly Predicted : 205.0
# Accuracy for validation Sample 94 is :0.9888780381944444
# # of White : 250, # of Black : 18182
# Correctly Predicted : 18143.0, Wrongly Predicted : 289.0
# Accuracy for validation Sample 95 is :0.9843207465277778
# # of White : 285, # of Black : 18147
# Correctly Predicted : 18227.0, Wrongly Predicted : 205.0
# Accuracy for validation Sample 96 is :0.9888780381944444
# # of White : 277, # of Black : 18155
# Correctly Predicted : 18204.0, Wrongly Predicted : 228.0
# Accuracy for validation Sample 97 is :0.9876302083333334
# # of White : 303, # of Black : 18129
# Correctly Predicted : 18223.0, Wrongly Predicted : 209.0
# Accuracy for validation Sample 98 is :0.9886610243055556
# # of White : 206, # of Black : 18226
# Correctly Predicted : 18276.0, Wrongly Predicted : 156.0
# Accuracy for validation Sample 99 is :0.9915364583333334
# # of White : 295, # of Black : 18137
# Correctly Predicted : 18228.0, Wrongly Predicted : 204.0
# Accuracy for validation Sample 100 is :0.9889322916666666
# # of White : 309, # of Black : 18123
# Correctly Predicted : 18174.0, Wrongly Predicted : 258.0
# Accuracy for validation Sample 101 is :0.9860026041666666
# # of White : 264, # of Black : 18168
# Correctly Predicted : 18186.0, Wrongly Predicted : 246.0
# Accuracy for validation Sample 102 is :0.9866536458333334
# # of White : 293, # of Black : 18139
# Correctly Predicted : 18204.0, Wrongly Predicted : 228.0
# Accuracy for validation Sample 103 is :0.9876302083333334
# # of White : 268, # of Black : 18164
# Correctly Predicted : 18186.0, Wrongly Predicted : 246.0
# Accuracy for validation Sample 104 is :0.9866536458333334
# # of White : 267, # of Black : 18165
# Correctly Predicted : 18235.0, Wrongly Predicted : 197.0
# Accuracy for validation Sample 105 is :0.9893120659722222
# # of White : 247, # of Black : 18185
# Correctly Predicted : 18213.0, Wrongly Predicted : 219.0
# Accuracy for validation Sample 106 is :0.9881184895833334
# # of White : 279, # of Black : 18153
# Correctly Predicted : 18229.0, Wrongly Predicted : 203.0
# Accuracy for validation Sample 107 is :0.9889865451388888
# # of White : 294, # of Black : 18138
# Correctly Predicted : 18207.0, Wrongly Predicted : 225.0
# Accuracy for validation Sample 108 is :0.98779296875
# # of White : 304, # of Black : 18128
# Correctly Predicted : 18204.0, Wrongly Predicted : 228.0
# Accuracy for validation Sample 109 is :0.9876302083333334
# # of White : 319, # of Black : 18113
# Correctly Predicted : 18145.0, Wrongly Predicted : 287.0
# Accuracy for validation Sample 110 is :0.9844292534722222
# # of White : 284, # of Black : 18148
# Correctly Predicted : 18164.0, Wrongly Predicted : 268.0
# Accuracy for validation Sample 111 is :0.9854600694444444
# # of White : 268, # of Black : 18164
# Correctly Predicted : 18213.0, Wrongly Predicted : 219.0
# Accuracy for validation Sample 112 is :0.9881184895833334
# # of White : 271, # of Black : 18161
# Correctly Predicted : 18232.0, Wrongly Predicted : 200.0
# Accuracy for validation Sample 113 is :0.9891493055555556
# # of White : 265, # of Black : 18167
# Correctly Predicted : 18232.0, Wrongly Predicted : 200.0
# Accuracy for validation Sample 114 is :0.9891493055555556
# # of White : 276, # of Black : 18156
# Correctly Predicted : 18179.0, Wrongly Predicted : 253.0
# Accuracy for validation Sample 115 is :0.9862738715277778
# # of White : 255, # of Black : 18177
# Correctly Predicted : 18186.0, Wrongly Predicted : 246.0
# Accuracy for validation Sample 116 is :0.9866536458333334
# # of White : 243, # of Black : 18189
# Correctly Predicted : 18242.0, Wrongly Predicted : 190.0
# Accuracy for validation Sample 117 is :0.9896918402777778
# # of White : 264, # of Black : 18168
# Correctly Predicted : 18173.0, Wrongly Predicted : 259.0
# Accuracy for validation Sample 118 is :0.9859483506944444
# # of White : 275, # of Black : 18157
# Correctly Predicted : 18230.0, Wrongly Predicted : 202.0
# Accuracy for validation Sample 119 is :0.9890407986111112
# # of White : 246, # of Black : 18186
# Correctly Predicted : 18223.0, Wrongly Predicted : 209.0
# Accuracy for validation Sample 120 is :0.9886610243055556
# # of White : 287, # of Black : 18145
# Correctly Predicted : 18168.0, Wrongly Predicted : 264.0
# Accuracy for validation Sample 121 is :0.9856770833333334
# # of White : 281, # of Black : 18151
# Correctly Predicted : 18191.0, Wrongly Predicted : 241.0
# Accuracy for validation Sample 122 is :0.9869249131944444
# # of White : 271, # of Black : 18161
# Correctly Predicted : 18231.0, Wrongly Predicted : 201.0
# Accuracy for validation Sample 123 is :0.9890950520833334
# # of White : 256, # of Black : 18176
# Correctly Predicted : 18193.0, Wrongly Predicted : 239.0
# Accuracy for validation Sample 124 is :0.9870334201388888
# # of White : 266, # of Black : 18166
# Correctly Predicted : 18162.0, Wrongly Predicted : 270.0
# Accuracy for validation Sample 125 is :0.9853515625
# # of White : 272, # of Black : 18160
# Correctly Predicted : 18173.0, Wrongly Predicted : 259.0
# Accuracy for validation Sample 126 is :0.9859483506944444
# # of White : 240, # of Black : 18192
# Correctly Predicted : 18251.0, Wrongly Predicted : 181.0
# Accuracy for validation Sample 127 is :0.9901801215277778
# # of White : 308, # of Black : 18124
# Correctly Predicted : 18192.0, Wrongly Predicted : 240.0
# Accuracy for validation Sample 128 is :0.9869791666666666

# %% [markdown]
# ##### Results

# %%
plt.title(f"Loss over the training")
plt.plot(train_losses)
plt.show()

# %%
print("Validation Loss : " + str(sum(validation_losses)/len(validation_losses)))
# Out:
# Validation Loss : 0.01546806573119863

# %%
print("Validation Accuracy : " + str(sum(validation_accuracy)/len(validation_accuracy)))
# Out:
# Validation Accuracy : 0.987672265288544

# %% [markdown]
# # Ouput Visualisation

# %%
sample_number = np.random.randint(129)

# %% [markdown]
# #### Sample Case :

# %%
with torch.no_grad():
    input = torch.from_numpy(val_x[sample_number]).float()
    input = torch.unsqueeze(input, axis = 0)
    input = input.to(device)

    # # changing from 10 x 96 x 192 x 3 to 10 x 3 x 96 x 192
    input = input.transpose(1, 3)
    input = input.transpose(2, 3)

    # 10 x 1 x 96 x 192
    output = torch.from_numpy(val_ground[sample_number]).float()
    output = torch.unsqueeze(output, axis = 0)
    output = output.to(device)

    output = output.transpose(1, 3)
    output = output.transpose(2, 3)

    predictions = model(input)
    predictions = torch.where(predictions >= 0.5, 1, 0)

    num_correct = (predictions == output).type(torch.float).sum().item()
    num_pixels = (float) (h*w)

    print("# of White : " + str((output != 0).sum().item()) + ", # of Black : " + str((output == 0).sum().item()))
    print("Correctly Predicted : " + str(num_correct) + ", Wrongly Predicted : " + str(num_pixels - num_correct))

    print("Accuracy for validation Sample " + str(i) + " is :" + str(num_correct / num_pixels))
# Out:
# # of White : 267, # of Black : 18165
# Correctly Predicted : 18235.0, Wrongly Predicted : 197.0
# Accuracy for validation Sample 128 is :0.9893120659722222

# %% [markdown]
# #### Visuals

# %%
broad_caster = np.ones(shape=(96, 192, 3))

# %%
with torch.no_grad():
    ip = torch.from_numpy(val_x[sample_number]).float()
    ip = torch.unsqueeze(ip, axis = 0)
    ip = ip.to(device)
    # # changing from 10 x 96 x 192 x 3 to 10 x 3 x 96 x 192
    ip = ip.transpose(1, 3)
    ip = ip.transpose(2, 3)

    y_pred = model(ip)

    y_pred = y_pred[0]

    y_pred = y_pred.transpose(0, 1)
    y_pred = y_pred.transpose(1, 2)

    y_pred = y_pred.cpu()
    y_pred = y_pred.numpy()

    plt.figure()
    f, axarr = plt.subplots(2,2, figsize=(17, 12)) 

    t = np.where(y_pred >= 0.5, y_pred, 0)

    axarr[0][0].title.set_text("Input Image")
    axarr[0][0].imshow(val_x[sample_number])

    axarr[0][1].title.set_text("Model Output Image")
    axarr[0][1].imshow(y_pred*broad_caster)

    axarr[1][0].title.set_text("Ground Truth")
    axarr[1][0].imshow(val_ground[sample_number]*broad_caster*100)
    
    axarr[1][1].title.set_text("Processed Output Image")
    axarr[1][1].imshow(t * broad_caster * 100)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
